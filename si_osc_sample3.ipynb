# %% [markdown]
# <a href="https://colab.research.google.com/github/kingAnunay/per-si_osc_project/blob/main/si_osc_sample3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install octave

# %%
# !pip install oct2py

# %%
from oct2py import octave

# %%
from math import pi as π
from numpy import sin as sin

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sam_rate = 44000 #Hz
frequency = 1000 #Hz

# %%
f = np.arange(1,sam_rate,1)

# %%
tone = sin(2*frequency*(f/sam_rate))

# %%
plt.xlim(1,1000)
plt.plot(tone)

# %%
# !pip install octave_kernel
# import octave

# %%
octave.wavwrite(tone,sam_rate,'test-tone.wav')
